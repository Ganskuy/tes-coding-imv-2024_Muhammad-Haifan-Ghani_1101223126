# %% [markdown]
# ## Load and Open Image

# %% [markdown]
# ## Using CV2
# Opening new windows for showing image

# %%
import cv2 

img = cv2.imread("winter.jpg")
cv2.imshow("Hello There!",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import glob
path = glob.glob("*.jpg")

for file in path:
    img = cv2.imread(file)
    cv2.imshow("gambar",img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %% [markdown]
# pixels information

# %%
import numpy as np  
import cv2  
img = cv2.imread("winter.jpg",1)  

pixel = img[100,100]  
print(pixel)
# Out:
# [158 146 212]

# %% [markdown]
# ### SAVE IMAGE

# %%
cv2.imwrite('winter_new.png', img)
# Out:
# True

# %% [markdown]
# ### SHOWING IMAGE Using matplotlib

# %%
# perlu pip lagi
from matplotlib import pyplot as plt #untuk import library
from matplotlib import image as mpimg
 
plt.title("Kebakaran Dek")
plt.xlabel("X =1800 pixel")
plt.ylabel("Y =1800 pixels")
 
image = mpimg.imread("fire.jpg")
plt.imshow(image)
plt.show()

# %% [markdown]
# ## Stacking (menumpuk gambar) dan Concatenate
# Menggabungkan dua citra yang berbeda dalam satu window yang sama. Terdapat dua cara dalam melakukannya, yakni dengan vstack dan hstack, serta dengan menggunakan concatenate. Perbedaan stack dan concatenate terletak pada sumbunya, dimana bila stack menggabungkan gambar disepanjang sumbu baru dan concatenate menggabungkan gambar disepanjang sumbu yang sudah ada.

# %%
import cv2 
import numpy as np 
 
img = cv2.imread('yuqi.jpg') 
img_hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV) 
 
np_vertical = np.vstack((img,img_hsv)) 
np_horizontal =np.hstack((img,img_hsv)) 

cv2.imshow("Vertical Stack", np_vertical) 
cv2.imshow("Horizontal Stack", np_horizontal) 

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

img = cv2.imread('lena.png') 
img_hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV) 
 
vertical_concat=np.concatenate((img,img_hsv),axis=0) 
horizontal_concat=np.concatenate((img,img_hsv),axis =1) 

cv2.imshow("Vertical Concatenate", vertical_concat) 
cv2.imshow("Horizontal Concatenate", horizontal_concat) 
 
cv2.waitKey(0) 
cv2.destroyAllWindows()

# %% [markdown]
# ### Kita lanjut ke resize yang gampang aja dulu

# %%
#resize
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
import cv2

img=cv2.imread('face.jpg',cv2.IMREAD_COLOR)
img_ = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) 
print("Panjang",img.shape[0])
print("Lebar",img.shape[1])
b=cv2.resize(img,(1920,1080))


fig = plt.figure(figsize=(30,30))
ax1 = fig.add_subplot(1,4,1)
ax1.set_title("ORI")
ax1.set_xlabel("1000 pixels")
ax1.set_ylabel('563 pixels')
ax1.imshow(img_)
ax2 = fig.add_subplot(1,4,2)
ax2.set_title("resize")
ax2.set_xlabel("1920 pixels")
ax2.set_ylabel('1080 pixels')
ax2.imshow(b)
# Out:
# Panjang 563
# Lebar 1000

# %% [markdown]
# ### Orienting using CV2 library
# Subplot untuk multiple pictures

# %%
#Orientasi gambar
from matplotlib import pyplot as plt
from matplotlib import image as mpimg


plt.title("Dek Awas Ada Api")
plt.xlabel("X pixel scaling")
plt.ylabel("Y pixels scaling")
 
image = plt.imread("fire.jpg")
plt.imshow(image)
img_90=cv2.rotate(image,cv2.ROTATE_90_CLOCKWISE)
img_180=cv2.rotate(image,cv2.ROTATE_180)
img_270=cv2.rotate(image,cv2.ROTATE_90_COUNTERCLOCKWISE)
img_flip=cv2.flip(image, 10)

fig = plt.figure(figsize=(20,20))

ax1 = fig.add_subplot(1,5,1)
ax1.set_title("ORI")
ax1.imshow(image)
ax2 = fig.add_subplot(1,5,2)
ax2.set_title("90CW")
ax2.imshow(img_90)
ax3 = fig.add_subplot(1,5,3)
ax3.set_title("180")
ax3.imshow(img_180)
ax4 = fig.add_subplot(1,5,4)
ax4.set_title("90CCW")
ax4.imshow(img_270)
ax5 = fig.add_subplot(1,5,5)
ax5.set_title("Flip Horizontal")
ax5.imshow(img_flip)

# %% [markdown]
# Flip using Numpy
# Perbedaan terletak pada hasil flip yang disimpan dalam file berbeda

# %%
import numpy as np
from PIL import Image
flipimage= np.array(Image.open('fire.jpg'))
print(type(flipimage))

print(flipimage.shape)
# (225, 400, 3)

Image.fromarray(np.rot90(flipimage)).save('fire90.jpg')

Image.fromarray(np.rot90(flipimage, 2)).save('fire.png180.jpg')

Image.fromarray(np.rot90(flipimage, 3)).save('fire.png270.jpg')
# Out:
# <class 'numpy.ndarray'>
# (1800, 1800, 3)

# %%
import cv2

img = cv2.imread('mountain.jpg') 
 
print('Original Dimensions : ',img.shape) 
 
scale_percent = 60
width = int(img.shape[1] * scale_percent / 100) 
height = int(img.shape[0] * scale_percent / 100) 
dim = (width, height) 

# resize image 
resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)

print('Resized Dimensions : ',resized.shape) 
 
cv2.imshow("Original image", img) 
cv2.imshow("Resized image", resized) 
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Original Dimensions :  (667, 1000, 3)
# Resized Dimensions :  (400, 600, 3)

# %% [markdown]
# Pada fungsi resize terdapat argumen interpolation dan nilainya cv2.INTER AREA. Interpolation atau interpolasi adalah suatu metode yang umumnya digunakan untuk melakukan resize pada citra. Cara kerja interpolasi adalah dengan menggunakan nilai matriks citra yang ada (yang akan di-resize) untuk mengestimasi nilai matriks pada titik-titik yang belum diketahui.
#
# Kemudian, untuk macam-macam nilai yang di-assign pada interpolation terdiri dari berbagai macam method disertai dengan contohnya, yakni:

# %% [markdown]
# #### a. INTER NEAREST : Interpolasi nearest-neighbor.
#
# Interpolasi jenis ini merupakan interpolasi paling sederhana. Dimana hasilnya diambil dari tetangga yang terdekat.

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("a.png")
resized = cv2.resize(img, (100,100), interpolation=cv2.INTER_NEAREST)

plt.subplot(1,2,1)
plt.title("default")
plt.xticks([])
plt.yticks([])
plt.imshow(img)

plt.subplot(1,2,2)
plt.title("Resized Inter Nearest")
plt.xticks([])
plt.yticks([])
plt.imshow(resized)

plt.show()

# %% [markdown]
# #### b. INTER LINEAR : Interpolasi bilinear (default)
#
# Interpolasi jenis INTER LINEAR ini dihasilkan melalui sumbu x linear dan sumbu y linear.

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("a.png")
resized = cv2.resize(img, (100,100), interpolation=cv2.INTER_LINEAR)

plt.subplot(1,2,1)
plt.title("default")
plt.xticks([])
plt.yticks([])
plt.imshow(img)

plt.subplot(1,2,2)
plt.title("Resized Inter Linear")
plt.xticks([])
plt.yticks([])
plt.imshow(resized)

plt.show()

# %% [markdown]
# #### c. INTER AREA : Melakukan resampling menggunakan relasi area piksel.
#
# INTER AREA merupakan method yang lebih disarankan untuk digunakan karena ia memberikan hasil citra yang moire-free.

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("a.png")
resized = cv2.resize(img, (100,100), interpolation=cv2.INTER_AREA)

plt.subplot(1,2,1)
plt.title("default")
plt.xticks([])
plt.yticks([])
plt.imshow(img)

plt.subplot(1,2,2)
plt.title("Resized Inter Area")
plt.xticks([])
plt.yticks([])
plt.imshow(resized)

plt.show()

# %% [markdown]
# # Color

# %%
warna = cv2.imread('car.jpg')
plt.imshow(warna)

# %%
warna = cv2.imread('car.jpg')
coloran=cv2.cvtColor(warna, cv2.COLOR_BGR2LAB)
plt.imshow(coloran)

# %%
img_bgr=cv2.cvtColor(warna, cv2.COLOR_BGR2RGB)
plt.imshow(img_bgr)

# %% [markdown]
# Nah coba lihat detailnya RGB sama BGR deh? kalau di grayscale bakal sama ga sih?

# %%
img_gray=cv2.cvtColor(warna, cv2.COLOR_RGB2GRAY)
plt.imshow(img_gray)

# %%
img_gray1=cv2.cvtColor(warna, cv2.COLOR_BGR2GRAY)
plt.imshow(img_gray1)

# %%
fig = plt.figure(figsize=(30,30))
ax1 = fig.add_subplot(1,4,1)
ax1.set_title("ORI Imread Color")
ax1.imshow(warna)
ax2 = fig.add_subplot(1,4,2)
ax2.set_title("grayscale")
ax2.imshow(img_gray)
ax3 =fig.add_subplot(1,4,3)
ax3.set_title('Ori BGR')
ax3.imshow(img_bgr)
ax4 = fig.add_subplot(1,4,4)
ax4.set_title('cie LAB')
ax4.imshow(coloran)
